# %%
# %run ./utils

# %%
STORAGE_ACCOUNT = "formula1dl02"

# %%
raw_folder_path = define_path("raw", STORAGE_ACCOUNT)
processed_folder_path = define_path("processed", STORAGE_ACCOUNT)
presentation_folder_path = define_path("presentation" , STORAGE_ACCOUNT)
