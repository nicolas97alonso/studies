# %%
# %run ./utils

# %%
STORAGE_ACCOUNT = "formula1dl02"

# %%
raw_folder_path = define_path(STORAGE_ACCOUNT, "raw")
processed_folder_path = define_path(STORAGE_ACCOUNT, "processed")
presentation_folder_path = define_path(STORAGE_ACCOUNT, "presentation")
