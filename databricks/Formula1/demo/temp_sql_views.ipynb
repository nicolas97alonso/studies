# %%
# %run "../utils/config"

# %%
race_results_df = spark.read.format("parquet").load(f"{presentation_folder_path}/race_results")

# %%
race_results_df.createOrReplaceTempView("v_race_results")

# %%
# %sql
select driver_name, sum(points) from v_race_results
where race_year = 2020
group by driver_name

# %%
v_race_year = 2020

# %%
driver_results_df_2019 = spark.sql(f"select * from v_race_results where race_year = {v_race_year}")
driver_results_df_2019.display()
